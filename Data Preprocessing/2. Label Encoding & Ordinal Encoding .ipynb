# %% [markdown]
# ### Ordinal and Nominal Variable

# %% [raw]
# Ordinal variables are the categorical variable in which the categories can be meaningful ordered in simple words we can
# measure
# Having Order
# Example : Rating of product (Good , Very Good, Poor, Excellent)
#
# Nominal variables are the categorical varible that we cann't measure in scale .
# Cann't have any order
# Example : (White ,Red, Yellow etc.) or (C,C++,Java,Python,etc)

# %% [markdown]
# ## Lable Encoding

# %% [raw]
# We apply on ordinal and nominal categorical variables. Example
#
# Grade   Object                                 Grade    Object
#
# A       Laptop                                   0      1
# B       Car    ----Converting Numerical ---->    1      0
# C       Mango                                    2      2
#
# Grade  Ordinal variable
# Object  Nominal variable
#
# Lable Encoding give numerical values based on the Alphabatical Order
#
# Lable Encoding will create impact on accuracy.

# %% [markdown]
# ## Ordinal Encoding

# %% [raw]
# We apply on ordinal categorical variables. Example
#
# Grade   Object                                 Grade    Object
#
# A       Laptop                                   3      Laptop
# B       Car    ----Converting Numerical ---->    2      Car
# C       Mango                                    1      Mango
#
# Grade  Ordinal variable
# Object  Nominal variable

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
dataFrame = pd.read_csv("D:\\dataSet\\train.csv")

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
dataFrame.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dataFrame.select_dtypes("object").columns   # all the categorical variable
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
DF2 = dataFrame[["KitchenQual","BldgType"]]

# %%
DF2.head()
# Out:
#   KitchenQual BldgType
# 0          Gd     1Fam
# 1          TA     1Fam
# 2          Gd     1Fam
# 3          Gd     1Fam
# 4          Gd     1Fam

# %% [markdown]
# # LabelEncoder

# %%
# Using class LabelEncoder
le = LabelEncoder()

# %%
le.fit_transform(DF2["BldgType"])
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
DF2['BldgType_Label_Encoding'] = le.fit_transform(DF2["BldgType"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12896\2478053977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF2['BldgType_Label_Encoding'] = le.fit_transform(DF2["BldgType"])

# %%
DF2.head(10)
# Out:
#   KitchenQual BldgType  BldgType_Label_Encoding  KitchenQual_Ord_Emcoding
# 0          Gd     1Fam                        0                         3
# 1          TA     1Fam                        0                         2
# 2          Gd     1Fam                        0                         3
# 3          Gd     1Fam                        0                         3
# 4          Gd     1Fam                        0                         3
# 5          TA     1Fam                        0                         2
# 6          Gd     1Fam                        0                         3
# 7          TA     1Fam                        0                         2
# 8          TA     1Fam                        0                         2
# 9          TA   2fmCon                        1                         2

# %% [markdown]
# # Ordinal Encoding

# %%
dataFrame["KitchenQual"].value_counts()
# Out:
# KitchenQual
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: count, dtype: int64

# %%
# Creating Order for Ordinal variable 

order_lable = {"Ex":4,"Gd":3,"TA":2,"Fa":1}

# %%
DF2["KitchenQual_Ord_Emcoding"] = DF2["KitchenQual"].map(order_lable)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12896\1591648155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF2["KitchenQual_Ord_Emcoding"] = DF2["KitchenQual"].map(order_lable)

# %%
DF2.head(20)
# Out:
#    KitchenQual BldgType  BldgType_Label_Encoding  KitchenQual_Ord_Emcoding
# 0           Gd     1Fam                        0                         3
# 1           TA     1Fam                        0                         2
# 2           Gd     1Fam                        0                         3
# 3           Gd     1Fam                        0                         3
# 4           Gd     1Fam                        0                         3
# 5           TA     1Fam                        0                         2
# 6           Gd     1Fam                        0                         3
# 7           TA     1Fam                        0                         2
# 8           TA     1Fam                        0                         2
# 9           TA   2fmCon                        1                         2
# 10          TA     1Fam                        0                         2
# ...
